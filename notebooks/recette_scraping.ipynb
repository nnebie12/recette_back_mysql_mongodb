# %%
import requests
import time
import re
import csv
import os
from bs4 import BeautifulSoup

# %%
header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

BASE_URLS = {
    "Italienne": "https://www.marmiton.org/dossier-viva-italia",
    "Japonaise": "https://www.marmiton.org/recettes/recherche.aspx?aqt=japon",
    "Libanaise": "https://www.marmiton.org/recettes/recherche.aspx?aqt=liban",
    "Indienne": "https://www.marmiton.org/recettes/recherche.aspx?aqt=inde",
    "Française": "https://www.marmiton.org/recettes/recherche.aspx?aqt=france",
    "Rapide et Facile": "https://www.marmiton.org/recettes/recherche.aspx?aqt=rapide-facile",
    "Anti-gaspillage": "https://www.marmiton.org/recettes/recherche.aspx?aqt=anti-gaspi",
}

# %%
OUTPUT_CSV = "recettes.csv"
DELAY_BETWEEN_REQUESTS = 1.5

# %%
def get_recipe_links(url):
    """Récupère les liens de recettes sur la page de recherche."""
    links = []
    try:
        response = requests.get(url, headers=header, timeout=15)
        if response.status_code != 200:
            print(f"  ⚠️ Erreur de connexion (Code {response.status_code})")
            return []
            
        soup = BeautifulSoup(response.text, "html.parser")
        
        for a in soup.find_all("a", href=True):
            href = a['href']
            if "/recettes/recette_" in href:
                full_url = href if href.startswith("http") else "https://www.marmiton.org" + href
                if full_url not in links:
                    links.append(full_url)
                    
    except Exception as e:
        print(f"  ❌ Erreur lors de la récupération : {e}")
        
    return links[:30] 
    

def parse_recipe(url, culture_theme):
    """Parse une page de recette et extrait les informations."""
    try:
        response = requests.get(url, headers=header, timeout=10)
        soup = BeautifulSoup(response.text, "html.parser")
        page_text = soup.get_text().lower()
        
        # Nom de la recette
        nom = soup.select_one("h1").get_text().strip() if soup.select_one("h1") else "N/A"
        
        # Note de la recette
        note = soup.select_one(".recipe-header__rating-text")
        note = note.get_text().strip() if note else "N/A"
        
        # --- GOÛTS ---
        gouts = []
        if "végétarien" in page_text or "vegetarien" in page_text: 
            gouts.append("Végétarien")
        if "sans gluten" in page_text: 
            gouts.append("Sans Gluten")
        if "végan" in page_text or "vegan" in page_text: 
            gouts.append("Végan")
        if "healthy" in page_text or "léger" in page_text: 
            gouts.append("Healthy")
        
        # --- INGREDIENTS ---
        ing_elements = soup.select(".recipe-ingredients__list__item, .card-ingredient-title")
        ingredients = [re.sub(r"\s+", " ", i.get_text()).strip() for i in ing_elements]
        
        return {
            "recette": nom,
            "thématique_culture": culture_theme,
            "goût": ", ".join(gouts) if gouts else "Standard",
            "ingredient": " | ".join(ingredients),
            "note": note
        }
    except Exception as e:
        print(f"    ❌ Erreur : {e}")
        return None

def main():
    dataset = []
    
    for theme, url in BASE_URLS.items():
        print(f"\n{'='*60}")
        print(f"🍴 Thème : {theme}")
        print(f"{'='*60}")
        links = get_recipe_links(url)
        print(f"📋 {len(links)} recettes trouvées\n")
        
        for i, link in enumerate(links, 1):
            data = parse_recipe(link, theme)
            if data:
                dataset.append(data)
                print(f"  [{i:2d}/{len(links)}] ✓ {data['recette'][:35]:35} | Note: {data['note']}")
            time.sleep(DELAY_BETWEEN_REQUESTS)
    
    print(f"\n{'='*60}")
    print("📊 STATISTIQUES")
    print(f"{'='*60}")
    for cat, count in stats.items():
        print(f" {count:3d} recettes")
    print(f"  {'TOTAL':10} : {len(dataset):3d} recettes")
    
    if dataset:
        keys = dataset[0].keys()
        with open(OUTPUT_CSV, "w", newline="", encoding="utf-8") as f:
            writer = csv.DictWriter(f, fieldnames=keys)
            writer.writeheader()
            writer.writerows(dataset)
        print(f"\n✅ Fichier '{OUTPUT_CSV}' créé avec succès !\n")
    else:
        print("\n⚠️ Aucune recette récupérée.\n")

if __name__ == "__main__":
    main()
# Out:
# ============================================================
# 🍴 Thème : Italienne
# ============================================================
# 📋 30 recettes trouvées
#
#   [ 1/30] ✓ Bruschetta (Italie)                 | Note: 4.3/5
#   [ 2/30] ✓ Focaccia                            | Note: 4.4/5
#   [ 3/30] ✓ Sauce pesto                         | Note: 3.8/5
#   [ 4/30] ✓ Gressins de Lili                    | Note: 4.9/5
#   [ 5/30] ✓ Crostinis                           | Note: 4.6/5
#   [ 6/30] ✓ Arancini di riso                    | Note: 3.7/5
#   [ 7/30] ✓ Taralli (biscuits salés italiens)   | Note: 4.7/5
#   [ 8/30] ✓ Gnocchis rôtis au parmesan et sauce | Note: 0/5
#   [ 9/30] ✓ Risotto aux champignons et tarte au | Note: 0/5
#   [10/30] ✓ Mini lasagnes individuelles au Airf | Note: 0/5
#   [11/30] ✓ Ragù arancini au Airfryer           | Note: 0/5
#   [12/30] ✓ Lasagnes à la bolognaise            | Note: 4.8/5
#   [13/30] ✓ Carbonara traditionnelle            | Note: 4.6/5
#   [14/30] ✓ Pâtes sauce bolognaise - Ragù bolog | Note: 5/5
#   [15/30] ✓ Linguini alle vongole               | Note: 4.4/5
#   [16/30] ✓ Spaghetti cacio e pepe              | Note: 4.8/5
#   [17/30] ✓ Penne à l'arrabbiata                | Note: 4.5/5
#   [18/30] ✓ Pâte à pizza fine                   | Note: 4.8/5
#   [19/30] ✓ Osso bucco de veau                  | Note: 4.9/5
#   [20/30] ✓ Risotto aux champignons : la vraie  | Note: 4.9/5
#   [21/30] ✓ Gnocchis faits maison               | Note: 4.6/5
#   [22/30] ✓ Polenta crémeuse                    | Note: 4.6/5
#   [23/30] ✓ Escalopes milanaises comme en Itali | Note: 4.8/5
#   [24/30] ✓ Tiramisu (recette originale)        | Note: 4.8/5
#   [25/30] ✓ Panna cotta                         | Note: 4.8/5
#   [26/30] ✓ Tiramisu aux speculoos              | Note: 4.8/5
#   [27/30] ✓ Panettone, recette secrète          | Note: 4.3/5
#   [28/30] ✓ Glace stracciatella                 | Note: 2.3/5
#   [29/30] ✓ Pandoro maison                      | Note: 1.8/5
#   [30/30] ✓ Gratin Dauphinois                   | Note: 4.7/5
#
# ============================================================
# 🍴 Thème : Japonaise
# ============================================================
# 📋 20 recettes trouvées
#
#   [ 1/20] ✓ Verrine lait de coco et perles du J | Note: 4.9/5
#   [ 2/20] ✓ Teriaky (Japon)                     | Note: 4.2/5
#   [ 3/20] ✓ yakiniku (Japon)                    | Note: 4.7/5
#   [ 4/20] ✓ Oyakodon (Japon)                    | Note: 4.3/5
#   [ 5/20] ✓ sauce teriyaki (Japon)              | Note: 5/5
#   [ 6/20] ✓ Yakitori / brochettes de poulet (Ja | Note: 4.3/5
#   [ 7/20] ✓ Perles du japon nature              | Note: 4.3/5
#   [ 8/20] ✓ Joues de porc laquées (Japon)       | Note: 4.5/5
#   [ 9/20] ✓ Perles du Japon au chocolat         | Note: 4.3/5
#   [10/20] ✓ Confiture de nèfles du Japon        | Note: 4.5/5
#   [11/20] ✓ Onigiri (Japon)                     | Note: 5/5
#   [12/20] ✓ Poulet tanuki (Japon)               | Note: 4.2/5
#   [13/20] ✓ Filets de limande du Japon en papil | Note: 5/5
#   [14/20] ✓ Soupe aux oeufs de grenouille (en v | Note: 5/5
#   [15/20] ✓ Perles du Japon sur lit de frambois | Note: 4/5
#   [16/20] ✓ Gratin Dauphinois                   | Note: 4.7/5
#   [17/20] ✓ Confit d'oignons ultra rapide       | Note: 4.7/5
#   [18/20] ✓ Tiramisu (recette originale)        | Note: 4.8/5
#   [19/20] ✓ Mayonnaise maison                   | Note: 4.5/5
#   [20/20] ✓ Fondue aux poireaux                 | Note: 4.7/5
#
# ============================================================
# 🍴 Thème : Libanaise
# ============================================================
# 📋 20 recettes trouvées
#
#   [ 1/20] ✓ Salade de pamplemousse et d'avocat  | Note: 4.6/5
#   [ 2/20] ✓ Purée de pois chiches / hoummos (Li | Note: 4.4/5
#   [ 3/20] ✓ Mehallabieh (Liban)                 | Note: 4.8/5
#   [ 4/20] ✓ Poulet Maronite ( Liban ) peu calor | Note: 4.4/5
#   [ 5/20] ✓ Merguez du Liban                    | Note: 4.7/5
#   [ 6/20] ✓ Brouchketta (Liban)                 | Note: 4.9/5
#   [ 7/20] ✓ Taboulé (Liban)                     | Note: 4.5/5
#   [ 8/20] ✓ Maamouls (Liban)                    | Note: 4.8/5
#   [ 9/20] ✓ Poulets aux pignons et amandes (Lib | Note: 4.6/5
#   [10/20] ✓ Poulet au citron (Liban)            | Note: 4.8/5
#   [11/20] ✓ Boulettes de fromage (Liban)        | Note: 4.3/5
#   [12/20] ✓ Taboulé simple (Liban)              | Note: 4.3/5
#   [13/20] ✓ Soupe aux lentilles du Liban (shorb | Note: 4.7/5
#   [14/20] ✓ Bamia (Liban)                       | Note: 5/5
#   [15/20] ✓ Kibbe naye (Liban)                  | Note: 4.5/5
#   [16/20] ✓ Gratin Dauphinois                   | Note: 4.7/5
#   [17/20] ✓ Confit d'oignons ultra rapide       | Note: 4.7/5
#   [18/20] ✓ Tiramisu (recette originale)        | Note: 4.8/5
#   [19/20] ✓ Mayonnaise maison                   | Note: 4.5/5
#   [20/20] ✓ Fondue aux poireaux                 | Note: 4.7/5
#
# ============================================================
# 🍴 Thème : Indienne
# ============================================================
# 📋 20 recettes trouvées
#
#   [ 1/20] ✓ Curry de crevettes (Sud de l'Inde)  | Note: 4.7/5
#   [ 2/20] ✓ Butter chicken ou poulet Makkhani ( | Note: 4.7/5
#   [ 3/20] ✓ Poulet tikka (Inde)                 | Note: 4.7/5
#   [ 4/20] ✓ Raïta de concombre (Inde)           | Note: 4.3/5
#   [ 5/20] ✓ Le vrai lassi à la mangue (Inde)    | Note: 4.8/5
#   [ 6/20] ✓ Besan paratha / beignets à la farin | Note: 4.8/5
#   [ 7/20] ✓ Poulet tikka facile (Inde)          | Note: 4.6/5
#   [ 8/20] ✓ Samossa (Inde)                      | Note: 4.4/5
#   [ 9/20] ✓ Gâteau de carottes (Inde)           | Note: 4.3/5
#   [10/20] ✓ Poulet korma (Inde)                 | Note: 4.2/5
#   [11/20] ✓ Curry de Pommes de terre et d'Epina | Note: 4.8/5
#   [12/20] ✓ Riz aux épices (Inde)               | Note: 4.6/5
#   [13/20] ✓ Chaï - thé indien (Inde du Sud)     | Note: 4.3/5
#   [14/20] ✓ Agneau korma (inde)                 | Note: 5/5
#   [15/20] ✓ Gâteau de riz au safran (Inde)      | Note: 4.8/5
#   [16/20] ✓ Gratin Dauphinois                   | Note: 4.7/5
#   [17/20] ✓ Confit d'oignons ultra rapide       | Note: 4.7/5
#   [18/20] ✓ Tiramisu (recette originale)        | Note: 4.8/5
#   [19/20] ✓ Mayonnaise maison                   | Note: 4.5/5
#   [20/20] ✓ Fondue aux poireaux                 | Note: 4.7/5
#
# ============================================================
# 🍴 Thème : Française
# ============================================================
# 📋 19 recettes trouvées
#
#   [ 1/19] ✓ Stoemp aux witloofs (chicons en Bel | Note: 4.6/5
#   [ 2/19] ✓ Coquilles de Noël ou Brioche à 2 tê | Note: 5/5
#   [ 3/19] ✓ Potjevlesch (Nord de la France)     | Note: 5/5
#   [ 4/19] ✓ Tarte à gros bords (nord de la Fran | Note: 4.2/5
#   [ 5/19] ✓ Tatin d'endives de la région Hauts- | Note: 5/5
#   [ 6/19] ✓ Bouchées à la reine, de la région I | Note: 5/5
#   [ 7/19] ✓ Tourtière de la Nouvelle France     | Note: 5/5
#   [ 8/19] ✓ Aumônières aux champignons, brie et | Note: 5/5
#   [ 9/19] ✓ Seiches au vin blanc de Tante Marie | Note: 5/5
#   [10/19] ✓ Riz à l'espagnole de Tante Marie-Fr | Note: 5/5
#   [11/19] ✓ Citrons confits 'made in France'    | Note: 5/5
#   [12/19] ✓ Cebiche Marie-France (Pérou)        | Note: 3/5
#   [13/19] ✓ Grissinis / gressins (Italie, Sud d | Note: 3.3/5
#   [14/19] ✓ Tarte au sucre (Nord de la France)  | Note: 0/5
#   [15/19] ✓ Gratin Dauphinois                   | Note: 4.7/5
#   [16/19] ✓ Confit d'oignons ultra rapide       | Note: 4.7/5
#   [17/19] ✓ Tiramisu (recette originale)        | Note: 4.8/5
#   [18/19] ✓ Mayonnaise maison                   | Note: 4.5/5
#   [19/19] ✓ Fondue aux poireaux                 | Note: 4.7/5
#
# ============================================================
# 🍴 Thème : Rapide et Facile
# ============================================================
# 📋 20 recettes trouvées
#
#   [ 1/20] ✓ Béchamel rapide et facile           | Note: 4.8/5
#   [ 2/20] ✓ Pancakes faciles et rapides         | Note: 4.8/5
#   [ 3/20] ✓ Cake à la banane facile et rapide   | Note: 4.7/5
#   [ 4/20] ✓ Tarte à la rhubarbe facile et rapid | Note: 4.6/5
#   [ 5/20] ✓ Gâteau à la ricotta facile et rapid | Note: 4.7/5
#   [ 6/20] ✓ Riz cantonais rapide et facile      | Note: 4.7/5
#   [ 7/20] ✓ Saucisson brioché facile et rapide  | Note: 4.5/5
#   [ 8/20] ✓ Lotte rapide et facile              | Note: 4.8/5
#   [ 9/20] ✓ mousse au chocolat rapide et facile | Note: 4.7/5
#   [10/20] ✓ Pâte sablée facile et rapide        | Note: 4.4/5
#   [11/20] ✓ Pâte à pain facile et rapide        | Note: 4.6/5
#   [12/20] ✓ Moelleux aux spéculoos facile et ra | Note: 4.8/5
#   [13/20] ✓ Verrine à l'avocat facile et rapide | Note: 4.4/5
#   [14/20] ✓ Ratatouille facile, rapide et pas c | Note: 4.6/5
#   [15/20] ✓ Tomates farcies à la viande hachée  | Note: 4.8/5
#   [16/20] ✓ Gratin Dauphinois                   | Note: 4.7/5
#   [17/20] ✓ Confit d'oignons ultra rapide       | Note: 4.7/5
#   [18/20] ✓ Tiramisu (recette originale)        | Note: 4.8/5
#   [19/20] ✓ Mayonnaise maison                   | Note: 4.5/5
#   [20/20] ✓ Fondue aux poireaux                 | Note: 4.7/5
#
# ============================================================
# 🍴 Thème : Anti-gaspillage
# ============================================================
# 📋 10 recettes trouvées
#
#   [ 1/10] ✓ Petit cake anti-gaspi aux peaux de  | Note: 5/5
#   [ 2/10] ✓ Pizza végétarienne anti-gaspi       | Note: 5/5
#   [ 3/10] ✓ Velouté de carottes anti-gaspi      | Note: 5/5
#   [ 4/10] ✓ Houmous de fèves (anti-gaspi)       | Note: 0/5
#   [ 5/10] ✓ Tomates farcies anti gaspi par Laur | Note: 0/5
#   [ 6/10] ✓ Gratin Dauphinois                   | Note: 4.7/5
#   [ 7/10] ✓ Confit d'oignons ultra rapide       | Note: 4.7/5
#   [ 8/10] ✓ Tiramisu (recette originale)        | Note: 4.8/5
#   [ 9/10] ✓ Mayonnaise maison                   | Note: 4.5/5
#   [10/10] ✓ Fondue aux poireaux                 | Note: 4.7/5
#
# ============================================================
# 📊 STATISTIQUES
# ============================================================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[114], line 100
#      97         print("\n⚠️ Aucune recette récupérée.\n")
#      99 if __name__ == "__main__":
# --> 100     main()
#
# Cell In[114], line 85, in main()
#      83 print("📊 STATISTIQUES")
#      84 print(f"{'='*60}")
# ---> 85 for cat, count in stats.items():
#      86     print(f"  {cat:10} : {count:3d} recettes")
#      87 print(f"  {'TOTAL':10} : {len(dataset):3d} recettes")
#
# NameError: name 'stats' is not defined
